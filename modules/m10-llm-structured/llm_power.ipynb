# %% [markdown]
# # Closed Source API Capabilities
#
# TODO:
# 1. GPT API (open ai api)
# 2. Gemini API (gemini ai api)
#
# # LLM Current Features - Base functionality
# 1. Text to Image
# 2. Q&A
# 3. Q&A on reference
# 4. Audio transcription
#
# ## LLM's current ability
# 1. LLM Application Patterns - General LLM Application Building, RAG LLMs, Custom Fine-tuned LLMs, Agentic LLM Application
# 2. Acting as general coding of intelligence (llm which can do general task you ask, llm which can also take actions)
#
# ## In this module, we focus on General LLM Application building with APIs, and custom AI Agentic applicaiton building

# %% [markdown]
# # Open Source LLM Capabilities

# %%
# Business Problem: Ticket Classification or something
from transformers import pipeline

pipe = pipeline(model="facebook/bart-large-mnli")
pipe("I have a problem with my iphone that needs to be resolved asap!",
    candidate_labels=["urgent", "not urgent", "phone", "tablet", "computer"],
)
# output
>>> {'sequence': 'I have a problem with my iphone that needs to be resolved asap!!', 'labels': ['urgent', 'phone', 'computer', 'not urgent', 'tablet'], 'scores': [0.504, 0.479, 0.013, 0.003, 0.002]}

# %%
# Business Problem: Word Type Identification. 
# Medical Term identificaiton, user details identification
from transformers import pipeline

classifier = pipeline("ner")
classifier("Hello I'm Omar and I live in Zürich.")

# %%
from transformers import pipeline

text2text_generator = pipeline("text2text-generation")

text2text_generator("translate from English to French: I'm very happy")
[{'generated_text': 'Je suis très heureux'}]

# %%
# Business Problem: Speech to Text - meeting transcribe
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", "openai/whisper-large-v3")

pipe("sample.flac")
# {'text': "GOING ALONG SLUSHY COUNTRY ROADS AND SPEAKING TO DAMP AUDIENCES IN DRAUGHTY SCHOOL ROOMS DAY AFTER DAY FOR A FORTNIGHT HE'LL HAVE TO PUT IN AN APPEARANCE AT SOME PLACE OF WORSHIP ON SUNDAY MORNING AND HE CAN COME TO US IMMEDIATELY AFTERWARDS"}

# %%
# Business Problem: Image Description and Understanding
from transformers import pipeline

captioner = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
captioner("https://huggingface.co/datasets/Narsil/image_dummy/resolve/main/parrots.png")
## [{'generated_text': 'two birds are standing next to each other '}]

# %%
# Context: Translation

# %% [markdown]
# # LLM's
#
# ## Details of LLM
# 1. Context Window , LLM's short term memory
# 2. Prompt Given to LLM to execute
# 3. LLM's general intelligence capabilities can do a task - (data synthesis and answer, validate with docs and answer etc)
# 4. LLM Output + Validation of output in Module 10
#
# ## LLM Application Building (Module 11, agentic AI)
# 1. LLM's ability to take outputs from multiple sources, syntheis , understand and give what user wants
# 2. Building Agentic LLM Application with framework + Python Functions + LLMs ability + Validated via Pydantic

# %% [markdown]
# # may be not so relevant capabilities of LLM
# # LLM APplication Building
# 4. Special purpose LLM's for specific functionalities
# 5. Special pov LLM's for specific role. (Improvement via reflection, generating 3 and combining best of 3, or any cost saving routing of LLMs )
#
# 5. LLM's extending knowledge base - Long term memory
# 6. Stitching custom functionality, with LLM's different capabilities
# 7. LLM's customizable knowledge base
