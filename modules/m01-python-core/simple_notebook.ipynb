# %% [markdown]
# ## Very expressive comments
# ### Section 1: Variable
# ### Section 2: Loops, If Else etc

# %%
first_variable = "hello world"
print(first_variable)

second_variable = 10
print(second_variable)
# Out:
# hello world
# 10

# %%
third_varaible = 11.11

# %%
print(third_varaible)
# Out:
# 11.11
